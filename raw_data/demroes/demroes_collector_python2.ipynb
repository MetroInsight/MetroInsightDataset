# %%
#Dependent to Python 2 lib

import requests
import wget
import json
import pykml
from pykml import parser

with open('config/demroes_config.json', 'r') as fp:
    config = json.load(fp)
with open('metadata/raw_demroes_metadata.kml') as fp:
    kml = pykml.parser.parse(fp)
    
for building_name, item in config.items():
    url = item['url']
    filename = 'raw_data/' + url.split('/')[-1]
    wget.download(url, out=filename)

# %%
print metadata_dict.findtext('BMSB')
# Out:
# None

# %%
a =

# %%
for aa in kml.iter():
    print aa
# Out:
# DEMROES.kml
# 1
#
#
# 1.3
#
# http://maps.google.com/mapfiles/kml/pushpin/ylw-pushpin.png
#
#
#
# normal
# #sn_ylw-pushpin00
#
# highlight
# #sh_ylw-pushpin50
#
#
# 1.1
#
# http://maps.google.com/mapfiles/kml/pushpin/ylw-pushpin.png
#
#
#
# 1.3
#
# http://maps.google.com/mapfiles/kml/pushpin/ylw-pushpin.png
#
#
#
# 1.3
#
# http://maps.google.com/mapfiles/kml/pushpin/ylw-pushpin.png
#
#
#
# 1.1
#
# http://maps.google.com/mapfiles/kml/pushpin/ylw-pushpin.png
#
#
#
# 1.1
#
# http://maps.google.com/mapfiles/kml/pushpin/ylw-pushpin.png
#
#
#
# normal
# #sn_ylw-pushpin0
#
# highlight
# #sh_ylw-pushpin500
#
#
# normal
# #sn_ylw-pushpin000
#
# highlight
# #sh_ylw-pushpin5
#
# DEMROES
# 1
#
# BMSB DEMROES
#
# -117.236190243
# 32.8773477923
# 0
# 0.00116217490075
# 81.2619356556
# 199.814663711
# relativeToSeaFloor
# #msn_ylw-pushpin21
#
# relativeToGround
# -117.236154350376,32.87580045163345,24
#
# CMRR DEMROES
#
# -117.235305071
# 32.8807653536
# 0
# 0.00156242704669
# 29.1285388146
# ...
